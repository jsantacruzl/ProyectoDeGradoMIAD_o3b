# %%
import pyodbc
import pandas as pd
import numpy as np
from sodapy import Socrata

# %% [markdown]
# ## Contratos Electrónicos

# %%
def iniciarSesion():
    server = 'tcp:miadgpproyecto.database.windows.net' 
    database = 'DB_GP_PROYECTO' 
    username = 'admin_miad' 
    password = 'Abc123456789' 
    
    cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
    cursor = cnxn.cursor()
    
    return cnxn, cursor

# %%
def leerDatos():
    client = Socrata("www.datos.gov.co", None)
    query = f"""SELECT nombre_entidad,
                        nit_entidad,
                        departamento,
                        ciudad,
                        localizaci_n,
                        orden,
                        sector,
                        rama,
                        entidad_centralizada,
                        proceso_de_compra,
                        id_contrato,
                        referencia_del_contrato,
                        estado_contrato,
                        codigo_de_categoria_principal,
                        tipo_de_contrato,
                        modalidad_de_contratacion,
                        justificacion_modalidad_de,
                        fecha_de_firma,
                        fecha_de_inicio_del_contrato,
                        fecha_de_fin_del_contrato,
                        fecha_de_inicio_de_ejecucion,
                        fecha_de_fin_de_ejecucion,
                        condiciones_de_entrega,
                        tipodocproveedor,
                        documento_proveedor,
                        proveedor_adjudicado,
                        es_grupo,
                        es_pyme,
                        habilita_pago_adelantado,
                        liquidaci_n,
                        obligaci_n_ambiental,
                        obligaciones_postconsumo,
                        reversion,
                        valor_del_contrato,
                        valor_de_pago_adelantado,
                        valor_facturado,
                        valor_pendiente_de_pago,
                        valor_pagado,
                        valor_amortizado,
                        valor_pendiente_de,
                        valor_pendiente_de_ejecucion,
                        estado_bpin,
                        c_digo_bpin,
                        anno_bpin,
                        saldo_cdp,
                        saldo_vigencia,
                        espostconflicto,
                        urlproceso,
                        destino_gasto,
                        origen_de_los_recursos,
                        dias_adicionados,
                        puntos_del_acuerdo,
                        pilares_del_acuerdo,
                        nombre_representante_legal,
                        nacionalidad_representante_legal,
                        tipo_de_identificaci_n_representante_legal,
                        identificaci_n_representante_legal,
                        g_nero_representante_legal,
                        presupuesto_general_de_la_nacion_pgn,
                        sistema_general_de_participaciones,
                        sistema_general_de_regal_as,
                        recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_,
                        recursos_de_credito,
                        recursos_propios,
                        ultima_actualizacion,
                        codigo_entidad,
                        fecha_inicio_liquidacion,
                        fecha_fin_liquidacion,
                        codigo_proveedor
                         WHERE tipo_de_contrato = 'Obra' LIMIT 19000 """
    results = client.get("jbjy-vk9h", query=query)
    results_df = pd.DataFrame.from_records(results)
    
    return results_df

# %%
def borrarContratosElectronicos():
    cnxn.execute("""TRUNCATE TABLE Test_Secop2_ContratosElectronicos""")
    cnxn.commit()
    print('Datos borrados')

# %%
def cargueContratosElectronicos(cnxn, cursor):
    print('Proceso iniciado')
    for index, row in results_df.iterrows():
        cursor.execute("""INSERT INTO Test_Secop2_ContratosElectronicos ([Nombre Entidad],
                        [Nit Entidad],
                        [Departamento],
                        [Ciudad],
                        [Localización],
                        [Orden],
                        [Sector],
                        [Rama],
                        [Entidad Centralizada],
                        [Proceso de Compra],
                        [ID Contrato],
                        [Referencia del Contrato],
                        [Estado Contrato],
                        [Codigo de Categoria Principal],
                        [Tipo de Contrato],
                        [Modalidad de Contratacion],
                        [Justificacion Modalidad de Contratacion],
                        [Fecha de Firma],
                        [Fecha de Inicio del Contrato],
                        [Fecha de Fin del Contrato],
                        [Fecha de Inicio de Ejecucion],
                        [Fecha de Fin de Ejecucion],
                        [Condiciones de Entrega],
                        [TipoDocProveedor],
                        [Documento Proveedor],
                        [Proveedor Adjudicado],
                        [Es Grupo],
                        [Es Pyme],
                        [Habilita Pago Adelantado],
                        [Liquidación],
                        [Obligación Ambiental],
                        [Obligaciones Postconsumo],
                        [Reversion],
                        [Valor del Contrato],
                        [Valor de pago adelantado],
                        [Valor Facturado],
                        [Valor Pendiente de Pago],
                        [Valor Pagado],
                        [Valor Amortizado],
                        [Valor Pendiente de Amortizacion],
                        [Valor Pendiente de Ejecucion],
                        [Estado BPIN],
                        [Código BPIN],
                        [Anno BPIN],
                        [Saldo CDP],
                        [Saldo Vigencia],
                        [EsPostConflicto],
                        [URLProceso],
                        [Destino Gasto],
                        [Origen de los Recursos],
                        [Dias Adicionados],
                        [Puntos del Acuerdo],
                        [Pilares del Acuerdo],
                        [Nombre Representante Legal],
                        [Nacionalidad Representante Legal],
                        [Tipo de Identificación Representante Legal],
                        [Identificación Representante Legal],
                        [Género Representante Legal],
                        [Presupuesto General de la Nacion – PGN],
                        [Sistema General de Participaciones],
                        [Sistema General de Regalías],
                        [Recursos Propios (Alcaldías, Gobernaciones y Resguardos Indígenas)],
                        [Recursos de Credito],
                        [Recursos Propios],
                        [Ultima Actualizacion],
                        [Codigo Entidad],
                        [Fecha Inicio Liquidacion],
                        [Fecha Fin Liquidacion],
                        [Codigo Proveedor]) values(?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?,
                                                    ?
                                                    )""", str(row.nombre_entidad),
                                                        str(row.nit_entidad),
                                                        str(row.departamento),
                                                        str(row.ciudad),
                                                        str(row.localizaci_n),
                                                        str(row.orden),
                                                        str(row.sector),
                                                        str(row.rama),
                                                        str(row.entidad_centralizada),
                                                        str(row.proceso_de_compra),
                                                        str(row.id_contrato),
                                                        str(row.referencia_del_contrato),
                                                        str(row.estado_contrato),
                                                        str(row.codigo_de_categoria_principal),
                                                        str(row.tipo_de_contrato),
                                                        str(row.modalidad_de_contratacion),
                                                        str(row.justificacion_modalidad_de),
                                                        str(row.fecha_de_firma),
                                                        str(row.fecha_de_inicio_del_contrato),
                                                        str(row.fecha_de_fin_del_contrato),
                                                        str(row.fecha_de_inicio_de_ejecucion),
                                                        str(row.fecha_de_fin_de_ejecucion),
                                                        str(row.condiciones_de_entrega),
                                                        str(row.tipodocproveedor),
                                                        str(row.documento_proveedor),
                                                        str(row.proveedor_adjudicado),
                                                        str(row.es_grupo),
                                                        str(row.es_pyme),
                                                        str(row.habilita_pago_adelantado),
                                                        str(row.liquidaci_n),
                                                        str(row.obligaci_n_ambiental),
                                                        str(row.obligaciones_postconsumo),
                                                        str(row.reversion),
                                                        str(row.valor_del_contrato),
                                                        str(row.valor_de_pago_adelantado),
                                                        str(row.valor_facturado),
                                                        str(row.valor_pendiente_de_pago),
                                                        str(row.valor_pagado),
                                                        str(row.valor_amortizado),
                                                        str(row.valor_pendiente_de),
                                                        str(row.valor_pendiente_de_ejecucion),
                                                        str(row.estado_bpin),
                                                        str(row.c_digo_bpin),
                                                        str(row.anno_bpin),
                                                        str(row.saldo_cdp),
                                                        str(row.saldo_vigencia),
                                                        str(row.espostconflicto),
                                                        str(row.urlproceso),
                                                        str(row.destino_gasto),
                                                        str(row.origen_de_los_recursos),
                                                        str(row.dias_adicionados),
                                                        str(row.puntos_del_acuerdo),
                                                        str(row.pilares_del_acuerdo),
                                                        str(row.nombre_representante_legal),
                                                        str(row.nacionalidad_representante_legal),
                                                        str(row.tipo_de_identificaci_n_representante_legal),
                                                        str(row.identificaci_n_representante_legal),
                                                        str(row.g_nero_representante_legal),
                                                        str(row.presupuesto_general_de_la_nacion_pgn),
                                                        str(row.sistema_general_de_participaciones),
                                                        str(row.sistema_general_de_regal_as),
                                                        str(row.recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_),
                                                        str(row.recursos_de_credito),
                                                        str(row.recursos_propios),
                                                        str(row.ultima_actualizacion),
                                                        str(row.codigo_entidad),
                                                        str(row.fecha_inicio_liquidacion),
                                                        str(row.fecha_fin_liquidacion),
                                                        str(row.codigo_proveedor))
    cnxn.commit()
    
    print('Datos cargados')

# %%
def cerrarCursor(cursor):
    try:
        cursor.close()
    except:
        pass

# %%
# 1. Se inicia la conexion con la base de datos
cnxn, cursor = iniciarSesion()

# 2. Se cargan los datos desde el API
results_df = leerDatos()

# 3. Se limipia la tabla para actualizar con los nuevos datos
borrarContratosElectronicos()

# 4. Se cargan los datos completos a la base SQL
cargueContratosElectronicos(cnxn, cursor)

# 5. Se cierra el cursor
cerrarCursor(cursor)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Datos borrados
# Proceso iniciado
# Datos cargados

# %%
sql = """
SELECT *
FROM Test_Secop2_ContratosElectronicos
"""

# %%
data = pd.read_sql(sql,cnxn)

# %%
data.head()
